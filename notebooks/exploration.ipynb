# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
very_rhs_2_no_ws = pd.read_csv('/Users/chang/PhD_workplace/MIPcc23/results/vary_rhs_series2_no_ws.csv')
very_rhs_2_ws_own = pd.read_csv('/Users/chang/PhD_workplace/MIPcc23/results/vary_rhs_series2_ws_own.csv')
very_rhs_2_ws_previous = pd.read_csv('/Users/chang/PhD_workplace/MIPcc23/results/vary_rhs_series2_ws_previous.csv')

# %%
plt.figure(figsize=(10,8))
plt.plot(very_rhs_2_no_ws.solve_time, label = 'no warmstart')
plt.plot(very_rhs_2_ws_own.solve_time, label = 'warmstart with best solution')
plt.plot(very_rhs_2_ws_previous.tot_time, label = 'warmstart with previous solutions')
plt.legend(bbox_to_anchor=(1.5, 1))
plt.ylabel('time in seconds')
plt.title('very_rhs_series2')
# Out:
# Text(0.5, 1.0, 'very_rhs_series2')

# %%
very_obj_1_no_ws = pd.read_csv('/Users/chang/PhD_workplace/MIPcc23/results/vary_obj_series1_no_ws.csv')
very_obj_1_ws_own = pd.read_csv('/Users/chang/PhD_workplace/MIPcc23/results/vary_obj_series1_ws_own.csv')
very_obj_1_ws_previous = pd.read_csv('/Users/chang/PhD_workplace/MIPcc23/results/vary_obj_series1_ws_previous.csv')

# %%
plt.figure(figsize=(10,8))
plt.plot(very_obj_1_no_ws.solve_time, label = 'no warmstart')
plt.plot(very_obj_1_ws_own.solve_time, label = 'warmstart with best solution')
plt.plot(very_obj_1_ws_previous.tot_time, label = 'warmstart with previous solutions')
plt.legend(bbox_to_anchor=(1.5, 1))
plt.ylim(0,800)
plt.ylabel('time in seconds')
plt.title('very_obj_series1')
# Out:
# Text(0.5, 1.0, 'very_obj_series1')

# %%
very_obj_1_ws_previous
# Out:
#     Unnamed: 0    instance solve_status  tot_solve_time  soln_check_time  \
# 0            0  obj_s1_i01      optimal      234.037292         0.001312
# 1            1  obj_s1_i02      optimal      153.346293         0.002597
# 2            2  obj_s1_i03      optimal      126.398816         0.003641
# 3            3  obj_s1_i04      optimal      168.938687         0.004002
# 4            4  obj_s1_i05      optimal      146.227153         0.003397
# 5            5  obj_s1_i06      optimal      153.177294         0.007419
# 6            6  obj_s1_i07      optimal      158.854072         0.008845
# 7            7  obj_s1_i08      optimal      143.532142         0.007963
# 8            8  obj_s1_i09      optimal      190.745071         0.005988
# 9            9  obj_s1_i10      optimal      197.713609         0.011838
# 10          10  obj_s1_i11      optimal      203.385021         0.012538
# 11          11  obj_s1_i12      optimal    14120.841067         0.012183
# ...
